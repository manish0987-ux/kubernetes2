# %% [markdown]
# Tasks To Be Performed:
# , Deploy a Kubernetes cluster for 3 node1
# ! Create a NGINX deployment of 3 replicasas

# %% [markdown]
# minikube start --nodes=3
# kubectl get nodes
# kubectl create deployment nginx-deployment --image=nginx
# kubectl scale deployment nginx-deployment --replicas=3
# kubectl get pods
# kubectl get deployment

# %% [markdown]
# Tasks To Be Performed:
# , Use the previous deployment
# ! Create a service of type NodePort for NGINX deployment
#  Check the NodePort service on a browser to verify

# %% [markdown]
# kubectl expose deployment nginx-deployment \
# --type=NodePort \
# --port=80
# kubectl get svc
# kubectl describe svc nginx-deployment

# %% [markdown]
# Tasks To Be Performed:
# , Use the previous deploymetO
# ! Change the replicas to 5 for the deployment

# %% [markdown]
# kubectl scale deployment nginx-deployment --replicas=5
# kubectl get pods

# %% [markdown]
# Tasks To Be Performed9
# , Use the previous deploymenO
# ! Change the service type to ClusterIP

# %% [markdown]
# kubectl delete svc nginx-deployment
# kubectl expose deployment nginx-deployment \
# --type=ClusterIP \
# --port=80
# kubectl get svc

# %% [markdown]
# Tasks To Be Performed
# , Use the previous deploymetO
# ! Deploy an NGINX deployment of 3 replica1
#  Create an NGINX service of type ClusterI3
# 	 Create an ingress service/ Apache to Apache service/ NGINX to NGINX ser
#
# vice

# %% [markdown]
# kubectl create deployment nginx-app --image=nginx
# kubectl scale deployment nginx-app --replicas=3
# kubectl expose deployment nginx-app \
# --type=ClusterIP \
# --port=80
# minikube addons enable ingress
# kubectl apply -f ingress.yaml
# kubectl get ingress
